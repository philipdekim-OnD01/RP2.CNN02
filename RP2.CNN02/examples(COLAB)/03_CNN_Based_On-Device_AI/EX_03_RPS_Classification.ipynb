# %% [markdown]
# # RFS Classification

# %% [markdown]
# ## 모듈 로딩

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import cv2
from sklearn.model_selection import train_test_split

print("NumPy Version :{}".format(np.__version__))
print("TensorFlow Version :{}".format(tf.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# NumPy Version :2.0.2
# TensorFlow Version :2.19.0
# Matplotlib Version :3.10.0

# %% [markdown]
# ## g-drive 마운트

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
    print('g-drive mounted.')
    colab=True
except:
    print('local drive.')
    colab =False
# Out:
# Mounted at /content/drive
# g-drive mounted.

# %% [markdown]
# ## RPS 데이터셋 준비

# %%
# files_path: 다른 경로에 실습파일을 복사했다면, 아래 경로를 수정하세요

if colab :
  # !unzip -q -o /content/drive/MyDrive/files/RPS_Dataset.zip
  files_path = '/content/RPS_Dataset'
else :
  files_path = '../files/RPS_Dataset'

# %% [markdown]
# ## 폴더 별로 파일 읽어 데이터화 진행

# %%
# %%time
first = True
IMG_SIZE = 64
for ind in range(0, 3, 1) :
    path = files_path + '/' + str(ind) + '/*.*'
    print(path)
    files = glob.glob(path)
    tmpx = np.array([(cv2.resize(cv2.cvtColor(cv2.imread(x, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB), (IMG_SIZE,IMG_SIZE))) for x in files])
    tmpy = np.array([ind] * len(files))

    xtrain, xtest, ytrain, ytest = train_test_split(tmpx, tmpy, test_size=0.2, random_state=123)

    if first == True:
        train_data = xtrain.copy()
        train_labels = ytrain.copy()
        test_data = xtest.copy()
        test_labels = ytest.copy()
        first = False
    else :
        train_data = np.concatenate((train_data, xtrain))
        train_labels = np.concatenate((train_labels, ytrain))
        test_data = np.concatenate((test_data, xtest))
        test_labels = np.concatenate((test_labels, ytest))
# Out:
# /content/RPS_Dataset/0/*.*
# /content/RPS_Dataset/1/*.*
# /content/RPS_Dataset/2/*.*
# CPU times: user 7.64 s, sys: 252 ms, total: 7.89 s
# Wall time: 8.05 s

# %% [markdown]
# ## 데이터 확인

# %%
# 0~1로 변환 처리 안함 (모델 내에서 처리함)
# train_data = train_data / 255.0
# test_data = test_data / 255.0

print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (2172, 64, 64, 3)
# (2172,)
# (545, 64, 64, 3)
# (545,)

# %% [markdown]
# ## 모델 생성

# %%
denseNet = tf.keras.applications.densenet.DenseNet121(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = tf.keras.applications.densenet.preprocess_input(inputs)
x = denseNet(x, training = False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 2, 2, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         3,075 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,040,579 (26.86 MB)
#  Trainable params: 6,956,931 (26.54 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %% [markdown]
# ## 모델 컴파일

# %%
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 학습 전 상황

# %%
def Make_Result_Plot(suptitle, data, label, y_max):
    size = data.shape[0]//10
    fig_result, ax_result = plt.subplots(2,5,figsize=(18, 7))
    fig_result.suptitle(suptitle)
    for idx in range(10):
        cnt = idx * size + size//2
        ax_result[idx//5,idx%5].imshow(data[cnt].reshape((IMG_SIZE,IMG_SIZE, 3)))
        ax_result[idx//5,idx%5].set_title("test_data[{}] (label : {} / y : {})".format(cnt, label[cnt], y_max[cnt]))

# %%
y_out = model.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("Before Training", test_data, test_labels, y_max)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 28s 736ms/step

# %% [markdown]
# ## 콜백 설정

# %%
savedModelName = 'RPS_PreTrained_DenseNet.keras'
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(savedModelName,
                                    save_best_only=True)
]

# %% [markdown]
# ## 모델 학습

# %%
# %%time
history = model.fit(train_data, train_labels, epochs=30,
                    callbacks=callbacks,
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 282s 2s/step - accuracy: 0.8155 - loss: 0.5248 - val_accuracy: 0.9615 - val_loss: 0.3839
# Epoch 2/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.9889 - loss: 0.0411 - val_accuracy: 0.9908 - val_loss: 0.0401
# Epoch 3/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.9942 - loss: 0.0219 - val_accuracy: 0.9835 - val_loss: 0.0301
# Epoch 4/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.9980 - loss: 0.0067 - val_accuracy: 0.9908 - val_loss: 0.0176
# Epoch 5/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9886 - loss: 0.0814 - val_accuracy: 0.9890 - val_loss: 0.0314
# Epoch 6/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.9952 - loss: 0.0145 - val_accuracy: 0.9541 - val_loss: 0.2846
# Epoch 7/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.9898 - loss: 0.0501 - val_accuracy: 0.9798 - val_loss: 0.1187
# Epoch 8/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9980 - loss: 0.0111 - val_accuracy: 0.9945 - val_loss: 0.0227
# Epoch 9/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.9982 - loss: 0.0050 - val_accuracy: 0.9963 - val_loss: 0.0091
# Epoch 10/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9963 - val_loss: 0.0069
# Epoch 11/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 1.0000 - loss: 9.4804e-04 - val_accuracy: 0.9963 - val_loss: 0.0145
# Epoch 12/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9988 - loss: 0.0105 - val_accuracy: 0.9982 - val_loss: 0.0110
# Epoch 13/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 1.0000 - loss: 4.8154e-04 - val_accuracy: 0.9982 - val_loss: 0.0117
# Epoch 14/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9991 - loss: 0.0073 - val_accuracy: 0.9945 - val_loss: 0.0136
# Epoch 15/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 1.0000 - loss: 3.3043e-04 - val_accuracy: 0.9963 - val_loss: 0.0118
# Epoch 16/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 1.0000 - loss: 1.4466e-04 - val_accuracy: 0.9963 - val_loss: 0.0113
# Epoch 17/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 1.0000 - loss: 1.2489e-04 - val_accuracy: 0.9963 - val_loss: 0.0101
# Epoch 18/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 1.0000 - loss: 3.8449e-04 - val_accuracy: 0.9963 - val_loss: 0.0102
# Epoch 19/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 8.2086e-05 - val_accuracy: 0.9963 - val_loss: 0.0122
# Epoch 20/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9974 - loss: 0.0073 - val_accuracy: 0.8294 - val_loss: 1.1567
# Epoch 21/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9737 - loss: 0.1023 - val_accuracy: 0.9560 - val_loss: 0.3516
# Epoch 22/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.9911 - loss: 0.0191 - val_accuracy: 0.9908 - val_loss: 0.0189
# Epoch 23/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9830 - loss: 0.0537 - val_accuracy: 0.9853 - val_loss: 0.0628
# Epoch 24/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.9992 - loss: 0.0098 - val_accuracy: 0.9963 - val_loss: 0.0259
# Epoch 25/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 4.2773e-04 - val_accuracy: 0.9982 - val_loss: 0.0096
# Epoch 26/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 3.3606e-04 - val_accuracy: 0.9963 - val_loss: 0.0102
# Epoch 27/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 1.0000 - loss: 1.6905e-04 - val_accuracy: 0.9963 - val_loss: 0.0095
# Epoch 28/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 1.0902e-04 - val_accuracy: 0.9963 - val_loss: 0.0087
# Epoch 29/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 1.1534e-04 - val_accuracy: 0.9963 - val_loss: 0.0082
# Epoch 30/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 1.0000 - loss: 8.7614e-05 - val_accuracy: 0.9963 - val_loss: 0.0080
# CPU times: user 5min 54s, sys: 11.1 s, total: 6min 5s
# Wall time: 6min 49s

# %% [markdown]
# ## Ploting : Cost/Training Count

# %%
plt.figure(figsize=(6, 10))
plt.subplot(2, 1, 1)
plt.title('Accuray')
plt.plot(history.history['accuracy'], 'b', label='train_accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='val_accuracy')
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(history.history['loss'], 'b', label='train_loss')
plt.plot(history.history['val_loss'], 'g', label='val_loss')
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## best 모델 로딩 및 테스트

# %%
model_best = tf.keras.models.load_model(savedModelName)

# %%
y_out = model_best.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("After Training", test_data, test_labels, y_max)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 651ms/step

# %% [markdown]
# ## best 모델 백업

# %%
# save_dir: 다른 경로에 저장하려면, 아래 경로를 수정하세요
if colab :
  save_dir = '/content/drive/MyDrive/files/save/'
else :
  save_dir = '../files/save/'

# %%
# copy saved mode
cpCmd = f'cp {savedModelName} {save_dir}'
print(cpCmd)
# !{cpCmd}
# Out:
# cp RPS_PreTrained_DenseNet.keras /content/drive/MyDrive/files/save/

# %% [markdown]
# ## LiteRT 모델로 변환

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_best)
tflite_model = converter.convert()
# Out:
# Saved artifact at '/tmp/tmp5mj3rek0'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   132139966638672: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132139966638864: TensorSpec(shape=(3,), dtype=tf.float32, name=None)
#   132142389078224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389076304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389075536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389076112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389074960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389069968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389072656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389074576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389075152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389077840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389075920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389075344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389078032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389077264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389071120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389074384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389074768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142704064464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389077456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389077072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389076880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389076496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389079760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389075728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132142389076688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703762768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703758544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703758352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703762000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703762384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703759120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703760080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703762192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703761424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703759312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093151440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139703762576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093150480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093150864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093151056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093151248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093152400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093151824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093152016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093152208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093150288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093153360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093152784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093152976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093153168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093150672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093154320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093153744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093153936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093154128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093151632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093155280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093154704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093154896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093155088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093152592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093156240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093155664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093155856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093156048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093153552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093157200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093156624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093156816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093157008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093154512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093158160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093157584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093157776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093157968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093155472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093159120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093158544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093158736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093158928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093156432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093160080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093159504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093159696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093159888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093157392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093161040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093160464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093160848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093158352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093162000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093161424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093161616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093161808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093159312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093162960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093162384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093162576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093162768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093160272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093163920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093163344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093163536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093163728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093161232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093164880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093164304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093164496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093164688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093162192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093165840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093165264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093165456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093166032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093166416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093165072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093164112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093165648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973072336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093166224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132138093163152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973072144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973072912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973073104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973072720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973074064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973073488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973073680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973073872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973071952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973075024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973074448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973074640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973074832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973072528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973075984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973075408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973075600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973075792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973073296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973076944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973076368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973076560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973076752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973074256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973077904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973077328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973077520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973077712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973075216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973078864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973078288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973078480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973078672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973076176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973079824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973079248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973079440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973079632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973077136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973080784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973080208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973080400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973080592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973078096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973081744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973081168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973081360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973081552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973079056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973082704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973082128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973082320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973082512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973080016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973083664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973083088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973083280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973083472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973080976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973084624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973084048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973084240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973084432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973081936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973085584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973085008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973085200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973085392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137973082896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132137